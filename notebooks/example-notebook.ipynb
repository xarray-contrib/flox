# %%
# %load_ext autoreload
# %autoreload 2

# %%
import xarray as xr
import dask_groupby
from dask_groupby.core import my_mean_func

# %%
ds = xr.tutorial.open_dataset("rasm")
ds

# %%
ds_x = my_mean_func(ds)
ds_x
